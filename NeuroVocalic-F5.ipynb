# %% [markdown]
# # 🚀 **NeuroVocalic-F5**
# ### **Creador: EndCharr | Autor: Academia EndCharr**
#
# Este es el cuaderno oficial de **NeuroVocalic-F5**, una implementación avanzada de F5-TTS optimizada para el habla en castellano. Esta versión incluye mejoras en el procesamiento de texto, conversión de números a palabras y una interfaz personalizada.
#
# ---

# %% [markdown]
# ## 🛠️ **Paso 1: Configuración del Entorno**
# Preparamos las dependencias del sistema y el motor de audio FFmpeg.

# %%
# --- PARTE 1: INSTALACIÓN Y CONFIGURACIÓN DE FFmpeg ---
# !sudo apt-get update && sudo apt-get install -y ffmpeg

# Añadimos la ruta de las librerías de FFmpeg a las variables de entorno
import os
os.environ['LD_LIBRARY_PATH'] = '/usr/lib/x86_64-linux-gnu:' + os.environ.get('LD_LIBRARY_PATH', '')

# --- PARTE 2: INSTALACIÓN DEL ECOSISTEMA PYTORCH ---
# Instalamos las versiones más recientes de PyTorch y sus librerías
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126

# --- PARTE 3: INSTALACIÓN EXPLÍCITA DE UNA VERSIÓN COMPATIBLE DE TORCHCODEC ---
# Según la tabla de compatibilidad, para PyTorch 2.9, la versión torchcodec 0.9 es compatible.
# Forzamos esta instalación para sobreescribir cualquier otra versión.
print("Instalando torchcodec==0.9 para asegurar la compatibilidad con PyTorch 2.9...")
# !pip install torchcodec==0.9

print("Configuración completada. Todas las librerías deberían ser ahora compatibles.")
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:6 https://cli.github.com/packages stable InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cpu)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.24.0+cpu)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.9.0+cpu)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Instalando torchcodec==0.9 para asegurar la compatibilidad con PyTorch 2.9...
# Collecting torchcodec==0.9
#   Downloading torchcodec-0.9.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (11 kB)
# Downloading torchcodec-0.9.0-cp312-cp312-manylinux_2_28_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 24.9 MB/s eta 0:00:00
# Installing collected packages: torchcodec
# Successfully installed torchcodec-0.9.0
# Configuración completada. Todas las librerías deberían ser ahora compatibles.

# %% [markdown]
# ## 📦 **Paso 2: Instalación de NeuroVocalic-F5**
# Instalamos la aplicación y sus dependencias optimizadas.
#
# > [!NOTE]
# > Hemos eliminado librerías inestables como `torchcodec` para garantizar la compatibilidad con las últimas versiones de PyTorch en Colab.

# %%
# @title Instalación desde Repositorio Oficial
# !pip install git+https://github.com/EndCharr/NeuroVocalic-F5.git

print("\n✅ NeuroVocalic-F5 ha sido instalado con éxito.")
# Out:
# Collecting git+https://github.com/EndCharr/NeuroVocalic-F5.git
#   Cloning https://github.com/EndCharr/NeuroVocalic-F5.git to /tmp/pip-req-build-eua6xbgd
#   Running command git clone --filter=blob:none --quiet https://github.com/EndCharr/NeuroVocalic-F5.git /tmp/pip-req-build-eua6xbgd
#   Resolved https://github.com/EndCharr/NeuroVocalic-F5.git to commit 94c07269e71cfa2426ffafa272174cea6e548763
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate>=0.33.0 in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (1.12.0)
# Requirement already satisfied: bitsandbytes>0.37.0 in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (0.49.1)
# Requirement already satisfied: cached_path in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (1.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (8.3.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (4.0.0)
# Requirement already satisfied: ema_pytorch>=0.5.2 in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (0.7.9)
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (5.50.0)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (0.36.0)
# Requirement already satisfied: jieba in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (0.42.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (0.11.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (3.10.0)
# Requirement already satisfied: num2words==0.5.13 in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (0.5.13)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (2.0.2)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (0.25.1)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (2.12.3)
# Requirement already satisfied: pypinyin in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (0.55.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (0.7.0)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (0.13.1)
# Requirement already satisfied: tomli in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (2.4.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (2.9.0+cpu)
# Requirement already satisfied: torchaudio>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (2.9.0+cpu)
# Requirement already satisfied: torchdiffeq in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (0.2.5)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (4.67.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (4.57.6)
# Requirement already satisfied: transformers_stream_generator in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (0.0.5)
# Requirement already satisfied: vocos in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (0.1.0)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (0.24.0)
# Requirement already satisfied: x_transformers>=1.31.14 in /usr/local/lib/python3.12/dist-packages (from NeuroVocalic-F5==0.0.0) (2.14.2)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from num2words==0.5.13->NeuroVocalic-F5==0.0.0) (0.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.33.0->NeuroVocalic-F5==0.0.0) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.33.0->NeuroVocalic-F5==0.0.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.33.0->NeuroVocalic-F5==0.0.0) (6.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->NeuroVocalic-F5==0.0.0) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->NeuroVocalic-F5==0.0.0) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->NeuroVocalic-F5==0.0.0) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->NeuroVocalic-F5==0.0.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->NeuroVocalic-F5==0.0.0) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->NeuroVocalic-F5==0.0.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->NeuroVocalic-F5==0.0.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->NeuroVocalic-F5==0.0.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->NeuroVocalic-F5==0.0.0) (3.1.6)
# Requirement already satisfied: einops>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from x_transformers>=1.31.14->NeuroVocalic-F5==0.0.0) (0.8.2)
# Requirement already satisfied: einx>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from x_transformers>=1.31.14->NeuroVocalic-F5==0.0.0) (0.3.0)
# Requirement already satisfied: loguru in /usr/local/lib/python3.12/dist-packages (from x_transformers>=1.31.14->NeuroVocalic-F5==0.0.0) (0.7.3)
# Requirement already satisfied: rich<14.0,>=12.1 in /usr/local/lib/python3.12/dist-packages (from cached_path->NeuroVocalic-F5==0.0.0) (13.9.4)
# Requirement already satisfied: boto3<2.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from cached_path->NeuroVocalic-F5==0.0.0) (1.42.38)
# Requirement already satisfied: google-cloud-storage<4.0,>=1.32.0 in /usr/local/lib/python3.12/dist-packages (from cached_path->NeuroVocalic-F5==0.0.0) (3.8.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->NeuroVocalic-F5==0.0.0) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->NeuroVocalic-F5==0.0.0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets->NeuroVocalic-F5==0.0.0) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->NeuroVocalic-F5==0.0.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets->NeuroVocalic-F5==0.0.0) (0.70.16)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (4.12.1)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (0.123.10)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (1.0.0)
# Requirement already satisfied: gradio-client==1.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (1.14.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (0.28.1)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (3.11.5)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (11.3.0)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (0.0.22)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (0.14.14)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (0.50.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (0.21.1)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio->NeuroVocalic-F5==0.0.0) (0.40.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio->NeuroVocalic-F5==0.0.0) (15.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->NeuroVocalic-F5==0.0.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->NeuroVocalic-F5==0.0.0) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->NeuroVocalic-F5==0.0.0) (0.4.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa->NeuroVocalic-F5==0.0.0) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa->NeuroVocalic-F5==0.0.0) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from librosa->NeuroVocalic-F5==0.0.0) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->NeuroVocalic-F5==0.0.0) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->NeuroVocalic-F5==0.0.0) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa->NeuroVocalic-F5==0.0.0) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa->NeuroVocalic-F5==0.0.0) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa->NeuroVocalic-F5==0.0.0) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa->NeuroVocalic-F5==0.0.0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->NeuroVocalic-F5==0.0.0) (1.1.2)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile->NeuroVocalic-F5==0.0.0) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->NeuroVocalic-F5==0.0.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->NeuroVocalic-F5==0.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->NeuroVocalic-F5==0.0.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->NeuroVocalic-F5==0.0.0) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->NeuroVocalic-F5==0.0.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->NeuroVocalic-F5==0.0.0) (2.9.0.post0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->NeuroVocalic-F5==0.0.0) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->NeuroVocalic-F5==0.0.0) (0.22.2)
# Requirement already satisfied: encodec==0.1.1 in /usr/local/lib/python3.12/dist-packages (from vocos->NeuroVocalic-F5==0.0.0) (0.1.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->NeuroVocalic-F5==0.0.0) (3.1.46)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb->NeuroVocalic-F5==0.0.0) (4.5.1)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb->NeuroVocalic-F5==0.0.0) (5.29.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->NeuroVocalic-F5==0.0.0) (2.50.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio->NeuroVocalic-F5==0.0.0) (3.11)
# Requirement already satisfied: botocore<1.43.0,>=1.42.38 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0,>=1.0->cached_path->NeuroVocalic-F5==0.0.0) (1.42.38)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0,>=1.0->cached_path->NeuroVocalic-F5==0.0.0) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0,>=1.0->cached_path->NeuroVocalic-F5==0.0.0) (0.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile->NeuroVocalic-F5==0.0.0) (3.0)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.12/dist-packages (from einx>=0.3.0->x_transformers>=1.31.14->NeuroVocalic-F5==0.0.0) (2.4.7)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio->NeuroVocalic-F5==0.0.0) (0.0.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->NeuroVocalic-F5==0.0.0) (3.13.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->NeuroVocalic-F5==0.0.0) (4.0.12)
# Requirement already satisfied: google-auth<3.0.0,>=2.26.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage<4.0,>=1.32.0->cached_path->NeuroVocalic-F5==0.0.0) (2.43.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage<4.0,>=1.32.0->cached_path->NeuroVocalic-F5==0.0.0) (2.29.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage<4.0,>=1.32.0->cached_path->NeuroVocalic-F5==0.0.0) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage<4.0,>=1.32.0->cached_path->NeuroVocalic-F5==0.0.0) (2.8.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage<4.0,>=1.32.0->cached_path->NeuroVocalic-F5==0.0.0) (1.8.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->NeuroVocalic-F5==0.0.0) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->NeuroVocalic-F5==0.0.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio->NeuroVocalic-F5==0.0.0) (0.16.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa->NeuroVocalic-F5==0.0.0) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->NeuroVocalic-F5==0.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->NeuroVocalic-F5==0.0.0) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->NeuroVocalic-F5==0.0.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->NeuroVocalic-F5==0.0.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->NeuroVocalic-F5==0.0.0) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<14.0,>=12.1->cached_path->NeuroVocalic-F5==0.0.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich<14.0,>=12.1->cached_path->NeuroVocalic-F5==0.0.0) (2.19.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa->NeuroVocalic-F5==0.0.0) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->NeuroVocalic-F5==0.0.0) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->NeuroVocalic-F5==0.0.0) (1.5.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->NeuroVocalic-F5==0.0.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->NeuroVocalic-F5==0.0.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->NeuroVocalic-F5==0.0.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->NeuroVocalic-F5==0.0.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->NeuroVocalic-F5==0.0.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->NeuroVocalic-F5==0.0.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->NeuroVocalic-F5==0.0.0) (1.22.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->NeuroVocalic-F5==0.0.0) (5.0.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage<4.0,>=1.32.0->cached_path->NeuroVocalic-F5==0.0.0) (1.72.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage<4.0,>=1.32.0->cached_path->NeuroVocalic-F5==0.0.0) (1.27.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage<4.0,>=1.32.0->cached_path->NeuroVocalic-F5==0.0.0) (6.2.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage<4.0,>=1.32.0->cached_path->NeuroVocalic-F5==0.0.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage<4.0,>=1.32.0->cached_path->NeuroVocalic-F5==0.0.0) (4.9.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<14.0,>=12.1->cached_path->NeuroVocalic-F5==0.0.0) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.26.1->google-cloud-storage<4.0,>=1.32.0->cached_path->NeuroVocalic-F5==0.0.0) (0.6.2)
#
# ✅ NeuroVocalic-F5 ha sido instalado con éxito.

# %% [markdown]
# ## 🚀 **Paso 3: Lanzar la Aplicación**
# Ejecuta la celda para abrir la interfaz web de Gradio. Podrás usar el enlace público generado para acceder desde cualquier navegador.

# %%
# @title Abrir Interfaz de NeuroVocalic-F5
# !f5-tts_infer-gradio --share
# Out:
# 2026-01-30 04:20:19.532375: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-30 04:20:19.572463: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-30 04:20:19.607070: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769746819.649850    5382 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769746819.664659    5382 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769746819.703194    5382 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769746819.703322    5382 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769746819.703330    5382 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769746819.703337    5382 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-30 04:20:19.714119: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# Download Vocos from huggingface charactr/vocos-mel-24khz
#
# vocab :  /usr/local/lib/python3.12/dist-packages/f5_tts/infer/examples/vocab.txt
# tokenizer :  custom
# model :  /root/.cache/huggingface/hub/models--jpgallegoar--F5-Spanish/snapshots/4765c14ffd01075479c2fde8615831acc0adca9a/model_1200000.safetensors
#
# Pre-loading ASR model (Whisper). This will run only once at startup.
# `torch_dtype` is deprecated! Use `dtype` instead!
# Device set to use cpu
# ASR model pre-loaded successfully.
# /usr/local/lib/python3.12/dist-packages/f5_tts/infer/infer_gradio.py:633: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot_interface = gr.Chatbot(label="Conversación")
# Iniciando la aplicación...
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://89470152374ec31fde.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Using `chunk_length_s` is very experimental with seq2seq models. The results will not necessarily be entirely accurate and will have caveats. More information: https://github.com/huggingface/transformers/pull/20104. Ignore this warning with pipeline(..., ignore_warning=True). To use Whisper for long-form transcription, use rather the model's `generate` method directly as the model relies on it's own chunking mechanism (cf. Whisper original paper, section 3.8. Long-form Transcription).
# gen_text 0 nota: el texto de referencia será transcrito automáticamente con whisper si no se proporciona. para mejores resultados,
# gen_text 1 mantén tus clips de referencia cortos (<quince s). asegúrate de que el audio esté completamente subido antes de generar.
# gen_text 2 se utiliza la librería num dos words para convertir los números a palabras..
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# DEBUG:jieba:Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.868 seconds.
# DEBUG:jieba:Loading model cost 0.868 seconds.
# Prefix dict has been built successfully.
# DEBUG:jieba:Prefix dict has been built successfully.

# %% [markdown]
# ---
# **Desarrollado por Academia EndCharr**
# Repositio: [GitHub NeuroVocalic-F5](https://github.com/EndCharr/NeuroVocalic-F5)
